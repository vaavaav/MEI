# %% [markdown]
# # DAA : Unsurpervied Learning
#
# **Data**: 18-11-2021
#
# ## Info
#
# **Nome**: José Pedro Ribeiro Peixoto<br>
# **Número**: PG47381<br>
# **Curso**: Mestrado em Engenharia Informática<br>

# %%
# Libs
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

def current_milli_time():
    return round(time.time() / 1000)

# Create some Data
from sklearn.datasets import make_blobs

data = make_blobs(n_samples=200, 
                  n_features=2,
                  centers=4,
                  cluster_std=1.8,
                  random_state=current_milli_time())

X = data[0]
y = data[1]

# View first 5 lines of Dataset
print('X:', X[0:5,:])
print('y:', y[0:5])

# Visualize Data
plt.scatter(X[:,0], X[:,1], c=y, cmap='rainbow')
# Out:
# X: [[12.11829634 -2.63233068]
#  [-8.24691951 -3.30208655]
#  [-9.76830336 -0.29449797]
#  [-5.10872315 -8.07259074]
#  [12.29458108 -4.41061554]]
# y: [2 1 1 1 2]
