# %% [markdown]
# # DAA : Ficha 6
#
# **Data**: 18-11-2021
#
# ## Info
#
# **Nome**: José Pedro Ribeiro Peixoto<br>
# **Número**: PG47381<br>
# **Curso**: Mestrado em Engenharia Informática<br>

# %%
# Libs

import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# Load dataset
df = pd.read_csv('College_Data.csv')

# Correlation Matrix
corr = df.corr()
plt.subplots(figsize=(10,10))
sns.heatmap(corr, vmin=-1, vmax=1, annot=True)
# Out:
# <AxesSubplot:>

# %%
X = df.drop(['Accept','F.Undergrad','Top10perc', 'Private', 'Name'],axis='columns')
# Correlation Matrix
corr = X.corr()
plt.subplots(figsize=(10,10))
sns.heatmap(corr, vmin=-1, vmax=1, annot=True)

y = df['Private']
# Out:
# 0      Yes
# 1      Yes
# 2      Yes
# 3      Yes
# 4      Yes
#       ...
# 772     No
# 773    Yes
# 774    Yes
# 775    Yes
# 776    Yes
# Name: Private, Length: 777, dtype: object

# %%
from sklearn.cluster import KMeans

kmeans = KMeans(n_clusters=2, random_state=2021)
kmeans.fit(X)

y_pred = kmeans.predict(X)
y_pred
y
# Out:
#     Private
# 0       Yes
# 1       Yes
# 2       Yes
# 3       Yes
# 4       Yes
# ..      ...
# 772      No
# 773     Yes
# 774     Yes
# 775     Yes
# 776     Yes
#
# [777 rows x 1 columns]
